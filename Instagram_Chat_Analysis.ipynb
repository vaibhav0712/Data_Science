# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('../instagram-vaibhav_712._/messages/inbox/dipal_17936674127081067/message_1.json') as f:
    print(f.read())
# Out:
# {
#   "participants": [
#     {
#       "name": "Dipal\u00f0\u009f\u0092\u00ab"
#     },
#     {
#       "name": "vaibhav_712._"
#     }
#   ],
#   "messages": [
#     {
#       "sender_name": "Dipal\u00f0\u009f\u0092\u00ab",
#       "timestamp_ms": 1692455158838,
#       "content": "Bruh\u00f0\u009f\u0098\u0082\u00f0\u009f\u0098\u0082",
#       "reactions": [
#         {
#           "reaction": "\u00f0\u009f\u0098\u0082",
#           "actor": "vaibhav_712._"
#         }
#       ]
#     },
#     {
#       "sender_name": "vaibhav_712._",
#       "timestamp_ms": 1692447262504,
#       "content": "But you are boy \u00f0\u009f\u0098\u0082"
#     },
#     {
#       "sender_name": "Dipal\u00f0\u009f\u0092\u00ab",
#       "timestamp_ms": 1687171244640,
#       "content": "Dipal\u00f0\u009f\u0092\u00ab sent an attachment.",
#       "reactions": [
#         {
#           "reaction": "\u00f0\u009f\u0098\u0082",
#           "actor": "vaibhav_712._"
#         }
#       ],
#       "share": {
# ...
